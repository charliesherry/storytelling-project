# %%
import pandas as pd
import numpy as np
import regex as re
import matplotlib.pyplot as plt
import seaborn as sns
from functions import ratingsearch
from functions import priceapp
from functions import currency

# %%
apps = pd.read_csv("/Users/Carlos/Desktop/Ironhack/REPOS/proyecto/storytelling-project/Data/msft.csv")

# %% [markdown]
# ### Aquí tenemos nuestra tabla de datos, compuesta por una lista de apps, con sus reviews, fecha, categoría y precio

# %%
apps
# Out:
#                                                    Name  Rating  \
# 0                                        Dynamic Reader     3.5
# 1     Chemistry, Organic Chemistry and Biochemistry-...     3.0
# 2                                            BookViewer     3.5
# 3                                    Brick Instructions     3.5
# 4     Introduction to Python Programming by GoLearni...     2.0
# ...                                                 ...     ...
# 5317                                            JS King     1.0
# 5318                                        MQTTSniffer     2.5
# 5319                      Dev Utils - JSON, CSV and XML     4.0
# 5320                                        Simply Text     4.0
# 5321                                                NaN     NaN
#
#       No of people Rated         Category        Date     Price
# 0                    268            Books  07-01-2014      Free
# 1                    627            Books  08-01-2014      Free
# ...

# %% [markdown]
# ### Lo primero, vamos a quitar los valores nulos de esta tabla, para facilitar la limpieza.

# %%
apps = apps.dropna()

# %% [markdown]
# ### Aquí he calculado una nueva columna, en la que se representa el numero de personas que han hecho el review, multiplicado por la review que han hecho, dándonos una cifra más representativa de las reviews.

# %%
apps["Total Rating"]= apps.Rating * apps["No of people Rated"]
# Out:
# <ipython-input-5-93b067aa4bd2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   apps["Total Rating"]= apps.Rating * apps["No of people Rated"]

# %%
apps.sort_values(["Total Rating"],ascending=False).head(20)
# Out:
#                                    Name  Rating  No of people Rated  \
# 1883                                ILN     5.0                 999
# 319                            TookBook     5.0                 998
# 3406  Contemplatio - Rosary with images     5.0                 998
# 3241                   Five Good Things     5.0                 996
# 2662                     Magenta Health     5.0                 993
# 1469                        BIOSToolKit     5.0                 989
# 2038                Parents Worship Day     5.0                 988
# 252                             Ask Sai     5.0                 988
# 5305                          Littledot     5.0                 987
# 4653                        See Tow Bus     5.0                 986
# 2497              EMS Monitoring Studio     5.0                 985
# 944                             Jot ERP     5.0                 984
# 2567                          STOPP app     5.0                 984
# ...

# %% [markdown]
# #### Luego, convertí el precio (Rupias indias) en euros, para poder representarlo en gráficas y que sea más facil de operar.

# %%
apps["Price"] = apps.Price.apply(lambda x: x.replace(",",""))
# Out:
# <ipython-input-7-339af3437c67>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   apps["Price"] = apps.Price.apply(lambda x: x.replace(",",""))

# %%
apps["Price"] = apps["Price"].apply(currency)
# Out:
# <ipython-input-8-8f1ea9dcbed6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   apps["Price"] = apps["Price"].apply(currency)

# %%
apps
# Out:
#                                                    Name  Rating  \
# 0                                        Dynamic Reader     3.5
# 1     Chemistry, Organic Chemistry and Biochemistry-...     3.0
# 2                                            BookViewer     3.5
# 3                                    Brick Instructions     3.5
# 4     Introduction to Python Programming by GoLearni...     2.0
# ...                                                 ...     ...
# 5316                                          Get Color     3.0
# 5317                                            JS King     1.0
# 5318                                        MQTTSniffer     2.5
# 5319                      Dev Utils - JSON, CSV and XML     4.0
# 5320                                        Simply Text     4.0
#
#       No of people Rated         Category        Date  Price  Total Rating
# 0                    268            Books  07-01-2014  0.000         938.0
# ...

# %% [markdown]
# #### Por último para la limpieza, he creado varias funciones, para facilitar la búsqueda de los datos.

# %%
ratingsearch(4)
# Out:
#                                Name  Rating  No of people Rated  \
# 8                        ACK Comics     4.0               460.0
# 10           Coding Made Easy - SQL     4.0               774.0
# 11                   Baani : Nitnem     4.0               533.0
# 12                        iMac® 101     4.0               707.0
# 13              Complete C Programs     4.0               687.0
# ...                             ...     ...                 ...
# 5295        RocketCake Professional     4.0               691.0
# 5310                       EditPlus     4.0               778.0
# 5311                  0x Hex Viewer     4.0               211.0
# 5319  Dev Utils - JSON, CSV and XML     4.0               862.0
# 5320                    Simply Text     4.0               386.0
#
#              Category        Date       Price
# 8               Books  20-12-2012        Free
# 10              Books  30-01-2018        Free
# 11              Books  29-08-2014        Free
# ...

# %%
priceapp("EditPlus")
# Out:
#    index       Price
# 0   5310  ₹ 1,899.00

# %%
apps_clean = apps

# %%
apps_clean
# Out:
#                                                    Name  Rating  \
# 0                                        Dynamic Reader     3.5
# 1     Chemistry, Organic Chemistry and Biochemistry-...     3.0
# 2                                            BookViewer     3.5
# 3                                    Brick Instructions     3.5
# 4     Introduction to Python Programming by GoLearni...     2.0
# ...                                                 ...     ...
# 5316                                          Get Color     3.0
# 5317                                            JS King     1.0
# 5318                                        MQTTSniffer     2.5
# 5319                      Dev Utils - JSON, CSV and XML     4.0
# 5320                                        Simply Text     4.0
#
#       No of people Rated         Category        Date  Price  Total Rating
# 0                    268            Books  07-01-2014  0.000         938.0
# ...

# %%
apps_clean.to_csv(r"/Users/Carlos/Desktop/Ironhack/REPOS/proyecto/storytelling-project/DataFile apps_clean.csv")
